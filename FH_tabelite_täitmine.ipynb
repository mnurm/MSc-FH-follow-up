# %%
import pandas as pd
# %matplotlib inline
df=pd.read_csv('Faili query-FH_set1_325indiv_genePLUS_medicationsConsolid-20220127.csv',sep=";")
oige=pd.read_csv('20211209_VARV_isikud-FH_set1-325indiv-genePLUS-BMI_person_portrait-20211122_MN.csv',sep=";")

# %%
print(df.head())
df
# Out:
#   Person skood  Person gender code  Person birthYear Person agreementDate  \
# 0   EGVD000064                   2              1972           2007-11-29
# 1   EGVD000064                   2              1972           2007-11-29
# 2   EGVD000064                   2              1972           2007-11-29
# 3   EGVD000064                   2              1972           2007-11-29
# 4   EGVD000064                   2              1972           2007-11-29
#
#    Person ageToday  Person deathYear MedicationConsolidated atc code  \
# 0             49.0               NaN                         D01AE15
# 1             49.0               NaN                         D01AE16
# 2             49.0               NaN                         M01AX05
# 3             49.0               NaN                         J01CR02
# 4             49.0               NaN                         R01AD08
#
#   MedicationConsolidated atc name MedicationConsolidated medicament  \
# ...

# %%
print(oige.head())
oige
# Out:
#   Person skood       Scode Vcode with variant All_Vcodes SNP array geno  \
# 0   EGVD000064  EGVD000064             V12985     V12985            0/1
# 1   EGVD000081  EGVD000081             V07285     V07285            0/1
# 2   EGVD000927  EGVD000927             V46059     V46059            0/1
# 3   EGVD000940  EGVD000940             V23156        NaN            NaN
# 4   EGVD002100  EGVD002100             V14661     V14661            0/1
#
#        rs_name      POS_GRCh37  REF  ALT  Gene Nucleotide change
# 0    rs5742904   chr2:21229160    C    T  APOB        c.10580G>A
# 1    rs5742904   chr2:21229160    C    T  APOB        c.10580G>A
# 2    rs5742904   chr2:21229160    C    T  APOB        c.10580G>A
# 3  rs766474188  chr19:11223954  NaN  NaN  LDLR        c.1187 G>C
# 4    rs5742904   chr2:21229160    C    T  APOB        c.10580G>A
#     Person skood       Scode Vcode with variant All_Vcodes SNP array geno  \
# ...

# %%
#FH table equivalence

#df1=pd.DataFrame({'x':df['POS ch37'],'NCBI':'', 'VarMap':''})

df1=df.copy()

df1['Vcode']=''
df1['rs_name']=''
df1['POS_GRCh37']=''
df1['REF']=''
df1['ALT']=''
df1['Gene']=''
df1['Nucleotide change']=''

for i in range (len(df1)):
    skood=df1['Person skood'][i]
    row_numbers=oige[oige['Person skood'] == skood].index[0]
    df1['Vcode'][i]=oige['Vcode with variant'][row_numbers]
    df1['rs_name'][i]=oige['rs_name'][row_numbers]
    df1['POS_GRCh37'][i]=oige['POS_GRCh37'][row_numbers]
    df1['REF'][i]=oige['REF'][row_numbers]
    df1['ALT'][i]=oige['ALT'][row_numbers]
    df1['Gene'][i]=oige['Gene'][row_numbers]
    df1['Nucleotide change'][i]=oige['Nucleotide change'][row_numbers]
    #chrom=str(df['CHROM'][i])
    #pos=str(int(df['POS ch37'][i]))
    #df1.NCBI[i]="chr" + chrom + ":" + pos
    #print(row_numbers,skood)

df1
# Out:
# <ipython-input-7-b6a360b362bd>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Vcode'][i]=oige['Vcode with variant'][row_numbers]
# <ipython-input-7-b6a360b362bd>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rs_name'][i]=oige['rs_name'][row_numbers]
# <ipython-input-7-b6a360b362bd>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['POS_GRCh37'][i]=oige['POS_GRCh37'][row_numbers]
# ...

# %%
df1.to_csv('20220206_VARV_FH_set1_325indiv_genePLUS_medicationsConsolid-20220127.csv',sep=",",header=True)

# %%
df1.to_excel('20220206_VARV_FH_set1_325indiv_genePLUS_medicationsConsolid-20220127.xlsx')
